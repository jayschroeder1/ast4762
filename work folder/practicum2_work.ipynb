# %%
import numpy as np 
import matplotlib.pyplot as plt

mu = 55
sig = 13
N= 1000

def random(mu, sig, N):
    sample = np.random.normal(mu, sig, N)
random(55, 13, 10)

outputs = []

for i in range(10):
    sample_i = random(55, 13, 10)
    outputs_i = [i, x, sig]
    outputs.append(outputs_i)

plt.plo
